# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

suji = pd.read_csv("suji.csv")

start_date = '2003-12-01'
end_date = '2022-12-01'
data = yf.download(['USDKRW=X'],start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data2 = data.resample(rule="M").mean()
data3 = data2[:-2]
data4 = data3["Close"]

# %%
data['Close'].plot()
data2["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
suji.max()
suji.min()
# Out:
# data     200312월
# value      -4024
# dtype: object

# %%
suji['value'].astype("int64")
# Out:
# 0      2975
# 1      2123
# 2      1207
# 3      1898
# 4       544
#        ...
# 221    3860
# 222    5610
# 223     791
# 224   -3049
# 225    1611
# Name: value, Length: 226, dtype: int64

# %%
data3 = data3.reset_index()

# %%
result = pd.concat([data3["Close"],suji["value"]],axis=1)
# result

# %%
fig, ax1 = plt.subplots()
ax1.plot(result['Close'], color = 'red', alpha = 0.5)
ax1.set_ylim(0, 2000)

ax2 = ax1.twinx()
ax2.plot(result['value'], color = 'blue', alpha = 0.5)
ax2.set_ylim(-4100, 14000)
# Out:
# (-4100.0, 14000.0)
